# %% [markdown]
# <a href="https://colab.research.google.com/github/NamunaRegmi/BigData/blob/main/Workshop2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Upload the Dataset

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3f6fe7fa-229e-4a8e-9340-c3e02a3aa406" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f6fe7fa-229e-4a8e-9340-c3e02a3aa406">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Load the Dataset

# %%
df = pd.read_csv("/content/GoldUSD.csv")

# %% [markdown]
# #Check first rows

# %%
df.head()
# Out:
#        Date        Open        High         Low       Close  Volume
# 0  30-08-00  273.899994  273.899994  273.899994  273.899994       0
# 1  31-08-00  274.799988  278.299988  274.799988  278.299988       0
# 2  01-09-00  277.000000  277.000000  277.000000  277.000000       0
# 3  05-09-00  275.799988  275.799988  275.799988  275.799988       2
# 4  06-09-00  274.200012  274.200012  274.200012  274.200012       0

# %% [markdown]
# #Check Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6399 entries, 0 to 6398
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    6399 non-null   object
#  1   Open    6399 non-null   float64
#  2   High    6399 non-null   float64
#  3   Low     6399 non-null   float64
#  4   Close   6399 non-null   float64
#  5   Volume  6399 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 300.1+ KB

# %% [markdown]
# #Statistical Summary

# %%
df.describe()
# Out:
#               Open         High          Low        Close         Volume
# count  6399.000000  6399.000000  6399.000000  6399.000000    6399.000000
# mean   1274.892437  1281.728724  1267.908032  1274.961009    4282.543522
# std     782.868133   788.800733   777.090788   783.122438   24051.637361
# min     255.000000   256.100006   255.000000   255.100006       0.000000
# 25%     651.000000   653.649994   649.149994   651.699982      23.000000
# 50%    1251.599976  1256.199951  1244.800049  1251.099976     117.000000
# 75%    1694.700012  1706.099976  1683.250000  1695.649964     450.500000
# max    5415.700195  5586.200195  5334.899902  5377.299805  386334.000000

# %% [markdown]
# #Check Missing Values

# %%
df.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %% [markdown]
# #Histogram

# %%
df.hist(figsize=(10,8))
plt.show()

# %% [markdown]
# #Correlation Matrix

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#             Open      High       Low     Close    Volume
# Open    1.000000  0.999908  0.999806  0.999755  0.033146
# High    0.999908  1.000000  0.999745  0.999833  0.032307
# Low     0.999806  0.999745  1.000000  0.999910  0.033785
# Close   0.999755  0.999833  0.999910  1.000000  0.032927
# Volume  0.033146  0.032307  0.033785  0.032927  1.000000

# %% [markdown]
# #Correlation Heatmap

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# #Boxplot

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df[['Open','High','Low','Close']])
plt.title("Boxplot of Gold Prices")
plt.show()

# %% [markdown]
# #Price Trend Over Time

# %%
df['Date'] = pd.to_datetime(df['Date'])

plt.figure(figsize=(12,6))
plt.plot(df['Date'], df['Close'])
plt.title("Gold Price Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.show()
# Out:
# /tmp/ipykernel_439/3692595209.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])
